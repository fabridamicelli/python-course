# %% [markdown]
# 1)

# %%
RAWDATA = """\
onset   duration    trial_type  rewards
13  0   options_partner  n/a
16  0   decision_risky_partner    25
20.072093   0   outcome_other_neg_partner      0
27.661415   0   options_solo       0
33.796415   0   decision_safe_solo     0
42.856121   0   outcome_safe_solo      0
45.391388   0   happiness_rating      34
56.883578   0   options_social   n/a
65.835578   0   decision_risky_social     21
74.897329   0   outcome_other_pos_social       0
85.472048   0   options_solo       0
95.852048   0   decision_safe_solo     0
108.889945  0   outcome_safe_solo      0
111.425148  0   happiness_rating      32
125.419236  0   options_partner   20
128.419236  0   decision_safe_partner     20
132.457838  0   outcome_safe_partner      20
142.032034  0   options_social    10
145.179034  0   decision_safe_social      10
152.239768  0   outcome_safe_social   10
154.774905  0   happiness_rating      36
170.170194  0   options_solo       0
182.227194  0   decision_safe_solo     0
190.285498  0   outcome_safe_solo      0
197.857785  0   options_social   -25
212.906785  0   decision_safe_social     -25
218.957288  0   outcome_safe_social  -25
221.492477  0   happiness_rating      34
232.567507  0   options_social    15
242.986507  0   decision_safe_social      15
250.031015  0   outcome_safe_social   15
257.603337  0   options_partner  n/a
260.603337  0   decision_risky_partner  18.5
265.909711  0   outcome_other_pos_partner      0
268.444998  0   happiness_rating      34
277.402022  0   options_partner  n/a
280.402022  0   decision_risky_partner     7
284.30704   0   outcome_other_neg_partner      0
290.878961  0   options_solo     n/a
299.346961  0   decision_risky_solo 12.5
306.390476  0   outcome_self_neg_solo      0
308.925866  0   happiness_rating      34
319.617418  0   options_solo      30
329.170418  0   decision_safe_solo    30
336.230193  0   outcome_safe_solo     30
348.806325  0   options_social   n/a
352.850325  0   decision_risky_social     10
362.900485  0   outcome_other_neg_social       0
365.43567   0   happiness_rating      36
378.229089  0   options_partner  -15
381.229089  0   decision_safe_partner    -15
387.035498  0   outcome_safe_partner     -15
395.608814  0   options_solo     -20
400.666814  0   decision_safe_solo   -20
409.71943   0   outcome_safe_solo    -20
412.254679  0   happiness_rating      36
425.698328  0   options_partner  -10
428.698328  0   decision_safe_partner    -10
432.586891  0   outcome_safe_partner     -10
441.160085  0   options_solo      10
450.962085  0   decision_safe_solo    10
462.009382  0   outcome_safe_solo     10
464.544614  0   happiness_rating      36
475.570105  0   options_partner    0
478.570105  0   decision_safe_partner      0
484.826744  0   outcome_safe_partner       0
497.386636  0   options_partner  n/a
500.386636  0   decision_risky_partner  24.5
505.04221   0   outcome_other_neg_partner      0
507.577445  0   happiness_rating      38
523.506321  0   options_solo     -25
533.417321  0   decision_safe_solo   -25
546.457133  0   outcome_safe_solo    -25
554.029535  0   options_partner   10
557.029535  0   decision_safe_partner     10
560.934817  0   outcome_safe_partner      10
563.470099  0   happiness_rating      38
580.800034  0   options_partner    0
583.800034  0   decision_safe_partner      0
588.005449  0   outcome_safe_partner       0
597.579626  0   options_partner  n/a
600.579626  0   decision_risky_partner    27
604.401331  0   outcome_other_neg_partner      0
606.936571  0   happiness_rating      36
618.979118  0   options_solo       0
625.361118  0   decision_safe_solo     0
633.406885  0   outcome_safe_solo      0
639.978503  0   options_social   n/a
646.360503  0   decision_risky_social    8.5
652.404718  0   outcome_other_neg_social       0
654.939858  0   happiness_rating      40
668.467306  0   options_partner  -30
671.467306  0   decision_safe_partner    -30
676.439628  0   outcome_safe_partner     -30
684.012275  0   options_partner  n/a
687.012275  0   decision_risky_partner    42
692.068261  0   outcome_other_neg_partner      0
694.603454  0   happiness_rating      38
707.663534  0   options_social   n/a
712.080534  0   decision_risky_social    4.5
725.126869  0   outcome_other_pos_social       0
732.699192  0   options_solo     -25
739.904192  0   decision_safe_solo   -25
749.962459  0   outcome_safe_solo    -25
752.497674  0   happiness_rating      36
764.590285  0   options_partner  -20
767.590285  0   decision_safe_partner    -20
771.662329  0   outcome_safe_partner     -20
779.234763  0   options_solo     -25
785.175763  0   decision_safe_solo   -25
792.228033  0   outcome_safe_solo    -25
794.763228  0   happiness_rating      36
809.024403  0   options_partner  n/a
812.024403  0   decision_risky_partner  13.5
816.046131  0   outcome_other_neg_partner      0
822.61811   0   options_social   n/a
827.36811   0   decision_risky_social     54
836.428364  0   outcome_other_pos_social       0
838.963641  0   happiness_rating      34
857.444384  0   options_social   -20
868.535384  0   decision_safe_social     -20
877.5931    0   outcome_safe_social  -20
886.166317  0   options_solo     -10
894.735317  0   decision_safe_solo   -10
902.795647  0   outcome_safe_solo    -10
905.330966  0   happiness_rating      34
919.60851   0   options_partner  -30
922.60851   0   decision_safe_partner    -30
928.932253  0   outcome_safe_partner     -30
936.504693  0   options_social   -30
939.278693  0   decision_safe_social     -30
949.331248  0   outcome_safe_social  -30
951.866476  0   happiness_rating      34
963.108331  0   options_social   -20
973.383331  0   decision_safe_social     -20
984.441376  0   outcome_safe_social  -20
995.01607   0   options_social   n/a
1001.53507  0   decision_risky_social     21
1009.593852 0   outcome_other_pos_social       0
1012.129125 0   happiness_rating      36
1027.791092 0   options_social   -15
1032.734092 0   decision_safe_social     -15
1043.786732 0   outcome_safe_social  -15
1054.361298 0   options_social    30
1061.830298 0   decision_safe_social      30
1070.890669 0   outcome_safe_social   30
1073.425867 0   happiness_rating      38
1083.566977 0   options_social   n/a
1090.877977 0   decision_risky_social     21
1101.93096  0   outcome_other_neg_social       0
1115.490485 0   options_partner  -30
1118.490485 0   decision_safe_partner    -30
1122.89696  0   outcome_safe_partner     -30
1125.432252 0   happiness_rating      38
1136.907599 0   options_solo       0
1141.245599 0   decision_safe_solo     0
1150.301231 0   outcome_safe_solo      0
1161.876605 0   options_solo       0
1167.021605 0   decision_safe_solo     0
1177.071675 0   outcome_safe_solo      0
1179.606882 0   happiness_rating      36
1192.600313 0   options_solo     n/a
1200.694313 0   decision_risky_solo -7.5
1211.748317 0   outcome_self_pos_solo      0
1217.318979 0   options_social   n/a
1225.156979 0   decision_risky_social      0
1233.214511 0   outcome_other_pos_social       0
1235.749697 0   happiness_rating      34
1253.413602 0   options_solo      30
1265.045602 0   decision_safe_solo    30
1273.095128 0   outcome_safe_solo     30
1280.667331 0   options_partner    0
1283.667331 0   decision_safe_partner      0
1291.525599 0   outcome_safe_partner       0
1294.060885 0   happiness_rating      34
1301.933544 0   options_social   n/a
1307.381544 0   decision_risky_social      9
1317.42882  0   outcome_other_pos_social       0
1326.001946 0   options_solo      25
1332.868946 0   decision_safe_solo    25
1339.929323 0   outcome_safe_solo     25
1342.464466 0   happiness_rating      32
1355.758003 0   options_partner   30
1358.758003 0   decision_safe_partner     30
1367.350136 0   outcome_safe_partner      30
1373.921441 0   options_solo     -25
1380.220441 0   decision_safe_solo   -25
1388.266282 0   outcome_safe_solo    -25
1390.801237 0   happiness_rating      34
1408.081464 0   options_partner  -15
1411.081464 0   decision_safe_partner    -15
1417.688532 0   outcome_safe_partner     -15
1427.263315 0   options_solo       0
1431.404315 0   decision_safe_solo     0
1439.455158 0   outcome_safe_solo      0
1441.990402 0   happiness_rating      34
1453.349179 0   options_social   -15
1457.004179 0   decision_safe_social     -15
1463.056746 0   outcome_safe_social  -15
1471.629709 0   options_social   n/a
1475.652709 0   decision_risky_social      6
1485.707198 0   outcome_other_neg_social       0
1488.24238  0   happiness_rating      36
1499.9513   0   options_solo     -25
1504.8203   0   decision_safe_solo   -25
1510.87643  0   outcome_safe_solo    -25
1523.452588 0   options_social    10
1530.307588 0   decision_safe_social      10
1539.364813 0   outcome_safe_social   10
1541.89997  0   happiness_rating      36
"""

# %% [markdown]
# 2)

# %%
for line in RAWDATA.splitlines():
    print(line)
# Out:
# onset   duration    trial_type  rewards
# 13  0   options_partner  n/a
# 16  0   decision_risky_partner    25
# 20.072093   0   outcome_other_neg_partner      0
# 27.661415   0   options_solo       0
# 33.796415   0   decision_safe_solo     0
# 42.856121   0   outcome_safe_solo      0
# 45.391388   0   happiness_rating      34
# 56.883578   0   options_social   n/a
# 65.835578   0   decision_risky_social     21
# 74.897329   0   outcome_other_pos_social       0
# 85.472048   0   options_solo       0
# 95.852048   0   decision_safe_solo     0
# 108.889945  0   outcome_safe_solo      0
# 111.425148  0   happiness_rating      32
# 125.419236  0   options_partner   20
# 128.419236  0   decision_safe_partner     20
# 132.457838  0   outcome_safe_partner      20
# 142.032034  0   options_social    10
# 145.179034  0   decision_safe_social      10
# 152.239768  0   outcome_safe_social   10
# 154.774905  0   happiness_rating      36
# 170.170194  0   options_solo       0
# 182.227194  0   decision_safe_solo     0
# 190.285498  0   outcome_safe_solo      0
# 197.857785  0   options_social   -25
# 212.906785  0   decision_safe_social     -25
# 218.957288  0   outcome_safe_social  -25
# 221.492477  0   happiness_rating      34
# 232.567507  0   options_social    15
# 242.986507  0   decision_safe_social      15
# 250.031015  0   outcome_safe_social   15
# 257.603337  0   options_partner  n/a
# 260.603337  0   decision_risky_partner  18.5
# 265.909711  0   outcome_other_pos_partner      0
# 268.444998  0   happiness_rating      34
# 277.402022  0   options_partner  n/a
# 280.402022  0   decision_risky_partner     7
# 284.30704   0   outcome_other_neg_partner      0
# 290.878961  0   options_solo     n/a
# 299.346961  0   decision_risky_solo 12.5
# 306.390476  0   outcome_self_neg_solo      0
# 308.925866  0   happiness_rating      34
# 319.617418  0   options_solo      30
# 329.170418  0   decision_safe_solo    30
# 336.230193  0   outcome_safe_solo     30
# 348.806325  0   options_social   n/a
# 352.850325  0   decision_risky_social     10
# 362.900485  0   outcome_other_neg_social       0
# 365.43567   0   happiness_rating      36
# 378.229089  0   options_partner  -15
# 381.229089  0   decision_safe_partner    -15
# 387.035498  0   outcome_safe_partner     -15
# 395.608814  0   options_solo     -20
# 400.666814  0   decision_safe_solo   -20
# 409.71943   0   outcome_safe_solo    -20
# 412.254679  0   happiness_rating      36
# 425.698328  0   options_partner  -10
# 428.698328  0   decision_safe_partner    -10
# 432.586891  0   outcome_safe_partner     -10
# 441.160085  0   options_solo      10
# 450.962085  0   decision_safe_solo    10
# 462.009382  0   outcome_safe_solo     10
# 464.544614  0   happiness_rating      36
# 475.570105  0   options_partner    0
# 478.570105  0   decision_safe_partner      0
# 484.826744  0   outcome_safe_partner       0
# 497.386636  0   options_partner  n/a
# 500.386636  0   decision_risky_partner  24.5
# 505.04221   0   outcome_other_neg_partner      0
# 507.577445  0   happiness_rating      38
# 523.506321  0   options_solo     -25
# 533.417321  0   decision_safe_solo   -25
# 546.457133  0   outcome_safe_solo    -25
# 554.029535  0   options_partner   10
# 557.029535  0   decision_safe_partner     10
# 560.934817  0   outcome_safe_partner      10
# 563.470099  0   happiness_rating      38
# 580.800034  0   options_partner    0
# 583.800034  0   decision_safe_partner      0
# 588.005449  0   outcome_safe_partner       0
# 597.579626  0   options_partner  n/a
# 600.579626  0   decision_risky_partner    27
# 604.401331  0   outcome_other_neg_partner      0
# 606.936571  0   happiness_rating      36
# 618.979118  0   options_solo       0
# 625.361118  0   decision_safe_solo     0
# 633.406885  0   outcome_safe_solo      0
# 639.978503  0   options_social   n/a
# 646.360503  0   decision_risky_social    8.5
# 652.404718  0   outcome_other_neg_social       0
# 654.939858  0   happiness_rating      40
# 668.467306  0   options_partner  -30
# 671.467306  0   decision_safe_partner    -30
# 676.439628  0   outcome_safe_partner     -30
# 684.012275  0   options_partner  n/a
# 687.012275  0   decision_risky_partner    42
# 692.068261  0   outcome_other_neg_partner      0
# 694.603454  0   happiness_rating      38
# 707.663534  0   options_social   n/a
# 712.080534  0   decision_risky_social    4.5
# 725.126869  0   outcome_other_pos_social       0
# 732.699192  0   options_solo     -25
# 739.904192  0   decision_safe_solo   -25
# 749.962459  0   outcome_safe_solo    -25
# 752.497674  0   happiness_rating      36
# 764.590285  0   options_partner  -20
# 767.590285  0   decision_safe_partner    -20
# 771.662329  0   outcome_safe_partner     -20
# 779.234763  0   options_solo     -25
# 785.175763  0   decision_safe_solo   -25
# 792.228033  0   outcome_safe_solo    -25
# 794.763228  0   happiness_rating      36
# 809.024403  0   options_partner  n/a
# 812.024403  0   decision_risky_partner  13.5
# 816.046131  0   outcome_other_neg_partner      0
# 822.61811   0   options_social   n/a
# 827.36811   0   decision_risky_social     54
# 836.428364  0   outcome_other_pos_social       0
# 838.963641  0   happiness_rating      34
# 857.444384  0   options_social   -20
# 868.535384  0   decision_safe_social     -20
# 877.5931    0   outcome_safe_social  -20
# 886.166317  0   options_solo     -10
# 894.735317  0   decision_safe_solo   -10
# 902.795647  0   outcome_safe_solo    -10
# 905.330966  0   happiness_rating      34
# 919.60851   0   options_partner  -30
# 922.60851   0   decision_safe_partner    -30
# 928.932253  0   outcome_safe_partner     -30
# 936.504693  0   options_social   -30
# 939.278693  0   decision_safe_social     -30
# 949.331248  0   outcome_safe_social  -30
# 951.866476  0   happiness_rating      34
# 963.108331  0   options_social   -20
# 973.383331  0   decision_safe_social     -20
# 984.441376  0   outcome_safe_social  -20
# 995.01607   0   options_social   n/a
# 1001.53507  0   decision_risky_social     21
# 1009.593852 0   outcome_other_pos_social       0
# 1012.129125 0   happiness_rating      36
# 1027.791092 0   options_social   -15
# 1032.734092 0   decision_safe_social     -15
# 1043.786732 0   outcome_safe_social  -15
# 1054.361298 0   options_social    30
# 1061.830298 0   decision_safe_social      30
# 1070.890669 0   outcome_safe_social   30
# 1073.425867 0   happiness_rating      38
# 1083.566977 0   options_social   n/a
# 1090.877977 0   decision_risky_social     21
# 1101.93096  0   outcome_other_neg_social       0
# 1115.490485 0   options_partner  -30
# 1118.490485 0   decision_safe_partner    -30
# 1122.89696  0   outcome_safe_partner     -30
# 1125.432252 0   happiness_rating      38
# 1136.907599 0   options_solo       0
# 1141.245599 0   decision_safe_solo     0
# 1150.301231 0   outcome_safe_solo      0
# 1161.876605 0   options_solo       0
# 1167.021605 0   decision_safe_solo     0
# 1177.071675 0   outcome_safe_solo      0
# 1179.606882 0   happiness_rating      36
# 1192.600313 0   options_solo     n/a
# 1200.694313 0   decision_risky_solo -7.5
# 1211.748317 0   outcome_self_pos_solo      0
# 1217.318979 0   options_social   n/a
# 1225.156979 0   decision_risky_social      0
# 1233.214511 0   outcome_other_pos_social       0
# 1235.749697 0   happiness_rating      34
# 1253.413602 0   options_solo      30
# 1265.045602 0   decision_safe_solo    30
# 1273.095128 0   outcome_safe_solo     30
# 1280.667331 0   options_partner    0
# 1283.667331 0   decision_safe_partner      0
# 1291.525599 0   outcome_safe_partner       0
# 1294.060885 0   happiness_rating      34
# 1301.933544 0   options_social   n/a
# 1307.381544 0   decision_risky_social      9
# 1317.42882  0   outcome_other_pos_social       0
# 1326.001946 0   options_solo      25
# 1332.868946 0   decision_safe_solo    25
# 1339.929323 0   outcome_safe_solo     25
# 1342.464466 0   happiness_rating      32
# 1355.758003 0   options_partner   30
# 1358.758003 0   decision_safe_partner     30
# 1367.350136 0   outcome_safe_partner      30
# 1373.921441 0   options_solo     -25
# 1380.220441 0   decision_safe_solo   -25
# 1388.266282 0   outcome_safe_solo    -25
# 1390.801237 0   happiness_rating      34
# 1408.081464 0   options_partner  -15
# 1411.081464 0   decision_safe_partner    -15
# 1417.688532 0   outcome_safe_partner     -15
# 1427.263315 0   options_solo       0
# 1431.404315 0   decision_safe_solo     0
# 1439.455158 0   outcome_safe_solo      0
# 1441.990402 0   happiness_rating      34
# 1453.349179 0   options_social   -15
# 1457.004179 0   decision_safe_social     -15
# 1463.056746 0   outcome_safe_social  -15
# 1471.629709 0   options_social   n/a
# 1475.652709 0   decision_risky_social      6
# 1485.707198 0   outcome_other_neg_social       0
# 1488.24238  0   happiness_rating      36
# 1499.9513   0   options_solo     -25
# 1504.8203   0   decision_safe_solo   -25
# 1510.87643  0   outcome_safe_solo    -25
# 1523.452588 0   options_social    10
# 1530.307588 0   decision_safe_social      10
# 1539.364813 0   outcome_safe_social   10
# 1541.89997  0   happiness_rating      36

# %%
# 3)
lines = list(RAWDATA.splitlines())

# %%
lines[:3]
# Out:
# ['onset   duration    trial_type  rewards',
#  '13  0   options_partner  n/a',
#  '16  0   decision_risky_partner    25']

# %%
# 4)
[tuple(line.split()) for line in lines]
# Out:
# [('onset', 'duration', 'trial_type', 'rewards'),
#  ('13', '0', 'options_partner', 'n/a'),
#  ('16', '0', 'decision_risky_partner', '25'),
#  ('20.072093', '0', 'outcome_other_neg_partner', '0'),
#  ('27.661415', '0', 'options_solo', '0'),
#  ('33.796415', '0', 'decision_safe_solo', '0'),
#  ('42.856121', '0', 'outcome_safe_solo', '0'),
#  ('45.391388', '0', 'happiness_rating', '34'),
#  ('56.883578', '0', 'options_social', 'n/a'),
#  ('65.835578', '0', 'decision_risky_social', '21'),
#  ('74.897329', '0', 'outcome_other_pos_social', '0'),
#  ('85.472048', '0', 'options_solo', '0'),
#  ('95.852048', '0', 'decision_safe_solo', '0'),
#  ('108.889945', '0', 'outcome_safe_solo', '0'),
#  ('111.425148', '0', 'happiness_rating', '32'),
#  ('125.419236', '0', 'options_partner', '20'),
#  ('128.419236', '0', 'decision_safe_partner', '20'),
#  ('132.457838', '0', 'outcome_safe_partner', '20'),
#  ('142.032034', '0', 'options_social', '10'),
#  ('145.179034', '0', 'decision_safe_social', '10'),
#  ('152.239768', '0', 'outcome_safe_social', '10'),
#  ('154.774905', '0', 'happiness_rating', '36'),
#  ('170.170194', '0', 'options_solo', '0'),
#  ('182.227194', '0', 'decision_safe_solo', '0'),
#  ('190.285498', '0', 'outcome_safe_solo', '0'),
#  ('197.857785', '0', 'options_social', '-25'),
#  ('212.906785', '0', 'decision_safe_social', '-25'),
#  ('218.957288', '0', 'outcome_safe_social', '-25'),
#  ('221.492477', '0', 'happiness_rating', '34'),
#  ('232.567507', '0', 'options_social', '15'),
#  ('242.986507', '0', 'decision_safe_social', '15'),
#  ('250.031015', '0', 'outcome_safe_social', '15'),
#  ('257.603337', '0', 'options_partner', 'n/a'),
#  ('260.603337', '0', 'decision_risky_partner', '18.5'),
#  ('265.909711', '0', 'outcome_other_pos_partner', '0'),
#  ('268.444998', '0', 'happiness_rating', '34'),
#  ('277.402022', '0', 'options_partner', 'n/a'),
#  ('280.402022', '0', 'decision_risky_partner', '7'),
#  ('284.30704', '0', 'outcome_other_neg_partner', '0'),
#  ('290.878961', '0', 'options_solo', 'n/a'),
#  ('299.346961', '0', 'decision_risky_solo', '12.5'),
#  ('306.390476', '0', 'outcome_self_neg_solo', '0'),
#  ('308.925866', '0', 'happiness_rating', '34'),
#  ('319.617418', '0', 'options_solo', '30'),
#  ('329.170418', '0', 'decision_safe_solo', '30'),
#  ('336.230193', '0', 'outcome_safe_solo', '30'),
#  ('348.806325', '0', 'options_social', 'n/a'),
#  ('352.850325', '0', 'decision_risky_social', '10'),
#  ('362.900485', '0', 'outcome_other_neg_social', '0'),
#  ('365.43567', '0', 'happiness_rating', '36'),
#  ('378.229089', '0', 'options_partner', '-15'),
#  ('381.229089', '0', 'decision_safe_partner', '-15'),
#  ('387.035498', '0', 'outcome_safe_partner', '-15'),
#  ('395.608814', '0', 'options_solo', '-20'),
#  ('400.666814', '0', 'decision_safe_solo', '-20'),
#  ('409.71943', '0', 'outcome_safe_solo', '-20'),
#  ('412.254679', '0', 'happiness_rating', '36'),
#  ('425.698328', '0', 'options_partner', '-10'),
#  ('428.698328', '0', 'decision_safe_partner', '-10'),
#  ('432.586891', '0', 'outcome_safe_partner', '-10'),
#  ('441.160085', '0', 'options_solo', '10'),
#  ('450.962085', '0', 'decision_safe_solo', '10'),
#  ('462.009382', '0', 'outcome_safe_solo', '10'),
#  ('464.544614', '0', 'happiness_rating', '36'),
#  ('475.570105', '0', 'options_partner', '0'),
#  ('478.570105', '0', 'decision_safe_partner', '0'),
#  ('484.826744', '0', 'outcome_safe_partner', '0'),
#  ('497.386636', '0', 'options_partner', 'n/a'),
#  ('500.386636', '0', 'decision_risky_partner', '24.5'),
#  ('505.04221', '0', 'outcome_other_neg_partner', '0'),
#  ('507.577445', '0', 'happiness_rating', '38'),
#  ('523.506321', '0', 'options_solo', '-25'),
#  ('533.417321', '0', 'decision_safe_solo', '-25'),
#  ('546.457133', '0', 'outcome_safe_solo', '-25'),
#  ('554.029535', '0', 'options_partner', '10'),
#  ('557.029535', '0', 'decision_safe_partner', '10'),
#  ('560.934817', '0', 'outcome_safe_partner', '10'),
#  ('563.470099', '0', 'happiness_rating', '38'),
#  ('580.800034', '0', 'options_partner', '0'),
#  ('583.800034', '0', 'decision_safe_partner', '0'),
#  ('588.005449', '0', 'outcome_safe_partner', '0'),
#  ('597.579626', '0', 'options_partner', 'n/a'),
#  ('600.579626', '0', 'decision_risky_partner', '27'),
#  ('604.401331', '0', 'outcome_other_neg_partner', '0'),
#  ('606.936571', '0', 'happiness_rating', '36'),
#  ('618.979118', '0', 'options_solo', '0'),
#  ('625.361118', '0', 'decision_safe_solo', '0'),
#  ('633.406885', '0', 'outcome_safe_solo', '0'),
#  ('639.978503', '0', 'options_social', 'n/a'),
#  ('646.360503', '0', 'decision_risky_social', '8.5'),
#  ('652.404718', '0', 'outcome_other_neg_social', '0'),
#  ('654.939858', '0', 'happiness_rating', '40'),
#  ('668.467306', '0', 'options_partner', '-30'),
#  ('671.467306', '0', 'decision_safe_partner', '-30'),
#  ('676.439628', '0', 'outcome_safe_partner', '-30'),
#  ('684.012275', '0', 'options_partner', 'n/a'),
#  ('687.012275', '0', 'decision_risky_partner', '42'),
#  ('692.068261', '0', 'outcome_other_neg_partner', '0'),
#  ('694.603454', '0', 'happiness_rating', '38'),
#  ('707.663534', '0', 'options_social', 'n/a'),
#  ('712.080534', '0', 'decision_risky_social', '4.5'),
#  ('725.126869', '0', 'outcome_other_pos_social', '0'),
#  ('732.699192', '0', 'options_solo', '-25'),
#  ('739.904192', '0', 'decision_safe_solo', '-25'),
#  ('749.962459', '0', 'outcome_safe_solo', '-25'),
#  ('752.497674', '0', 'happiness_rating', '36'),
#  ('764.590285', '0', 'options_partner', '-20'),
#  ('767.590285', '0', 'decision_safe_partner', '-20'),
#  ('771.662329', '0', 'outcome_safe_partner', '-20'),
#  ('779.234763', '0', 'options_solo', '-25'),
#  ('785.175763', '0', 'decision_safe_solo', '-25'),
#  ('792.228033', '0', 'outcome_safe_solo', '-25'),
#  ('794.763228', '0', 'happiness_rating', '36'),
#  ('809.024403', '0', 'options_partner', 'n/a'),
#  ('812.024403', '0', 'decision_risky_partner', '13.5'),
#  ('816.046131', '0', 'outcome_other_neg_partner', '0'),
#  ('822.61811', '0', 'options_social', 'n/a'),
#  ('827.36811', '0', 'decision_risky_social', '54'),
#  ('836.428364', '0', 'outcome_other_pos_social', '0'),
#  ('838.963641', '0', 'happiness_rating', '34'),
#  ('857.444384', '0', 'options_social', '-20'),
#  ('868.535384', '0', 'decision_safe_social', '-20'),
#  ('877.5931', '0', 'outcome_safe_social', '-20'),
#  ('886.166317', '0', 'options_solo', '-10'),
#  ('894.735317', '0', 'decision_safe_solo', '-10'),
#  ('902.795647', '0', 'outcome_safe_solo', '-10'),
#  ('905.330966', '0', 'happiness_rating', '34'),
#  ('919.60851', '0', 'options_partner', '-30'),
#  ('922.60851', '0', 'decision_safe_partner', '-30'),
#  ('928.932253', '0', 'outcome_safe_partner', '-30'),
#  ('936.504693', '0', 'options_social', '-30'),
#  ('939.278693', '0', 'decision_safe_social', '-30'),
#  ('949.331248', '0', 'outcome_safe_social', '-30'),
#  ('951.866476', '0', 'happiness_rating', '34'),
#  ('963.108331', '0', 'options_social', '-20'),
#  ('973.383331', '0', 'decision_safe_social', '-20'),
#  ('984.441376', '0', 'outcome_safe_social', '-20'),
#  ('995.01607', '0', 'options_social', 'n/a'),
#  ('1001.53507', '0', 'decision_risky_social', '21'),
#  ('1009.593852', '0', 'outcome_other_pos_social', '0'),
#  ('1012.129125', '0', 'happiness_rating', '36'),
#  ('1027.791092', '0', 'options_social', '-15'),
#  ('1032.734092', '0', 'decision_safe_social', '-15'),
#  ('1043.786732', '0', 'outcome_safe_social', '-15'),
#  ('1054.361298', '0', 'options_social', '30'),
#  ('1061.830298', '0', 'decision_safe_social', '30'),
#  ('1070.890669', '0', 'outcome_safe_social', '30'),
#  ('1073.425867', '0', 'happiness_rating', '38'),
#  ('1083.566977', '0', 'options_social', 'n/a'),
#  ('1090.877977', '0', 'decision_risky_social', '21'),
#  ('1101.93096', '0', 'outcome_other_neg_social', '0'),
#  ('1115.490485', '0', 'options_partner', '-30'),
#  ('1118.490485', '0', 'decision_safe_partner', '-30'),
#  ('1122.89696', '0', 'outcome_safe_partner', '-30'),
#  ('1125.432252', '0', 'happiness_rating', '38'),
#  ('1136.907599', '0', 'options_solo', '0'),
#  ('1141.245599', '0', 'decision_safe_solo', '0'),
#  ('1150.301231', '0', 'outcome_safe_solo', '0'),
#  ('1161.876605', '0', 'options_solo', '0'),
#  ('1167.021605', '0', 'decision_safe_solo', '0'),
#  ('1177.071675', '0', 'outcome_safe_solo', '0'),
#  ('1179.606882', '0', 'happiness_rating', '36'),
#  ('1192.600313', '0', 'options_solo', 'n/a'),
#  ('1200.694313', '0', 'decision_risky_solo', '-7.5'),
#  ('1211.748317', '0', 'outcome_self_pos_solo', '0'),
#  ('1217.318979', '0', 'options_social', 'n/a'),
#  ('1225.156979', '0', 'decision_risky_social', '0'),
#  ('1233.214511', '0', 'outcome_other_pos_social', '0'),
#  ('1235.749697', '0', 'happiness_rating', '34'),
#  ('1253.413602', '0', 'options_solo', '30'),
#  ('1265.045602', '0', 'decision_safe_solo', '30'),
#  ('1273.095128', '0', 'outcome_safe_solo', '30'),
#  ('1280.667331', '0', 'options_partner', '0'),
#  ('1283.667331', '0', 'decision_safe_partner', '0'),
#  ('1291.525599', '0', 'outcome_safe_partner', '0'),
#  ('1294.060885', '0', 'happiness_rating', '34'),
#  ('1301.933544', '0', 'options_social', 'n/a'),
#  ('1307.381544', '0', 'decision_risky_social', '9'),
#  ('1317.42882', '0', 'outcome_other_pos_social', '0'),
#  ('1326.001946', '0', 'options_solo', '25'),
#  ('1332.868946', '0', 'decision_safe_solo', '25'),
#  ('1339.929323', '0', 'outcome_safe_solo', '25'),
#  ('1342.464466', '0', 'happiness_rating', '32'),
#  ('1355.758003', '0', 'options_partner', '30'),
#  ('1358.758003', '0', 'decision_safe_partner', '30'),
#  ('1367.350136', '0', 'outcome_safe_partner', '30'),
#  ('1373.921441', '0', 'options_solo', '-25'),
#  ('1380.220441', '0', 'decision_safe_solo', '-25'),
#  ('1388.266282', '0', 'outcome_safe_solo', '-25'),
#  ('1390.801237', '0', 'happiness_rating', '34'),
#  ('1408.081464', '0', 'options_partner', '-15'),
#  ('1411.081464', '0', 'decision_safe_partner', '-15'),
#  ('1417.688532', '0', 'outcome_safe_partner', '-15'),
#  ('1427.263315', '0', 'options_solo', '0'),
#  ('1431.404315', '0', 'decision_safe_solo', '0'),
#  ('1439.455158', '0', 'outcome_safe_solo', '0'),
#  ('1441.990402', '0', 'happiness_rating', '34'),
#  ('1453.349179', '0', 'options_social', '-15'),
#  ('1457.004179', '0', 'decision_safe_social', '-15'),
#  ('1463.056746', '0', 'outcome_safe_social', '-15'),
#  ('1471.629709', '0', 'options_social', 'n/a'),
#  ('1475.652709', '0', 'decision_risky_social', '6'),
#  ('1485.707198', '0', 'outcome_other_neg_social', '0'),
#  ('1488.24238', '0', 'happiness_rating', '36'),
#  ('1499.9513', '0', 'options_solo', '-25'),
#  ('1504.8203', '0', 'decision_safe_solo', '-25'),
#  ('1510.87643', '0', 'outcome_safe_solo', '-25'),
#  ('1523.452588', '0', 'options_social', '10'),
#  ('1530.307588', '0', 'decision_safe_social', '10'),
#  ('1539.364813', '0', 'outcome_safe_social', '10'),
#  ('1541.89997', '0', 'happiness_rating', '36')]

# %%
# 5)
entries = []
for i, line in enumerate(lines):
    if i == 0:
        continue
    o, d, t, r = line.split()
    entries.append({
        "onset": o,
        "duration": d,
        "trial_type": t,
        "rewards": r, 
    })
entries
# Out:
# [{'onset': '13',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '16',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '25'},
#  {'onset': '20.072093',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '27.661415',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '33.796415',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '42.856121',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '45.391388',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '56.883578',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '65.835578',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '74.897329',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '85.472048',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '95.852048',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '108.889945',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '111.425148',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '32'},
#  {'onset': '125.419236',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '20'},
#  {'onset': '128.419236',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '20'},
#  {'onset': '132.457838',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '20'},
#  {'onset': '142.032034',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '10'},
#  {'onset': '145.179034',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '10'},
#  {'onset': '152.239768',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '10'},
#  {'onset': '154.774905',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '170.170194',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '182.227194',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '190.285498',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '197.857785',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-25'},
#  {'onset': '212.906785',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-25'},
#  {'onset': '218.957288',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-25'},
#  {'onset': '221.492477',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '232.567507',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '15'},
#  {'onset': '242.986507',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '15'},
#  {'onset': '250.031015',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '15'},
#  {'onset': '257.603337',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '260.603337',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '18.5'},
#  {'onset': '265.909711',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_partner',
#   'rewards': '0'},
#  {'onset': '268.444998',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '277.402022',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '280.402022',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '7'},
#  {'onset': '284.30704',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '290.878961',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': 'n/a'},
#  {'onset': '299.346961',
#   'duration': '0',
#   'trial_type': 'decision_risky_solo',
#   'rewards': '12.5'},
#  {'onset': '306.390476',
#   'duration': '0',
#   'trial_type': 'outcome_self_neg_solo',
#   'rewards': '0'},
#  {'onset': '308.925866',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '319.617418',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '30'},
#  {'onset': '329.170418',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '30'},
#  {'onset': '336.230193',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '30'},
#  {'onset': '348.806325',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '352.850325',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '10'},
#  {'onset': '362.900485',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '365.43567',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '378.229089',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-15'},
#  {'onset': '381.229089',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-15'},
#  {'onset': '387.035498',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-15'},
#  {'onset': '395.608814',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-20'},
#  {'onset': '400.666814',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-20'},
#  {'onset': '409.71943',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-20'},
#  {'onset': '412.254679',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '425.698328',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-10'},
#  {'onset': '428.698328',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-10'},
#  {'onset': '432.586891',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-10'},
#  {'onset': '441.160085',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '10'},
#  {'onset': '450.962085',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '10'},
#  {'onset': '462.009382',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '10'},
#  {'onset': '464.544614',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '475.570105',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '0'},
#  {'onset': '478.570105',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '484.826744',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '0'},
#  {'onset': '497.386636',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '500.386636',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '24.5'},
#  {'onset': '505.04221',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '507.577445',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '523.506321',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '533.417321',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '546.457133',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '554.029535',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '10'},
#  {'onset': '557.029535',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '10'},
#  {'onset': '560.934817',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '10'},
#  {'onset': '563.470099',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '580.800034',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '0'},
#  {'onset': '583.800034',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '588.005449',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '0'},
#  {'onset': '597.579626',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '600.579626',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '27'},
#  {'onset': '604.401331',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '606.936571',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '618.979118',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '625.361118',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '633.406885',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '639.978503',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '646.360503',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '8.5'},
#  {'onset': '652.404718',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '654.939858',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '40'},
#  {'onset': '668.467306',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-30'},
#  {'onset': '671.467306',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '676.439628',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-30'},
#  {'onset': '684.012275',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '687.012275',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '42'},
#  {'onset': '692.068261',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '694.603454',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '707.663534',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '712.080534',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '4.5'},
#  {'onset': '725.126869',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '732.699192',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '739.904192',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '749.962459',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '752.497674',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '764.590285',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-20'},
#  {'onset': '767.590285',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-20'},
#  {'onset': '771.662329',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-20'},
#  {'onset': '779.234763',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '785.175763',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '792.228033',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '794.763228',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '809.024403',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '812.024403',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '13.5'},
#  {'onset': '816.046131',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '822.61811',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '827.36811',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '54'},
#  {'onset': '836.428364',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '838.963641',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '857.444384',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-20'},
#  {'onset': '868.535384',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-20'},
#  {'onset': '877.5931',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-20'},
#  {'onset': '886.166317',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-10'},
#  {'onset': '894.735317',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-10'},
#  {'onset': '902.795647',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-10'},
#  {'onset': '905.330966',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '919.60851',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-30'},
#  {'onset': '922.60851',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '928.932253',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-30'},
#  {'onset': '936.504693',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-30'},
#  {'onset': '939.278693',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-30'},
#  {'onset': '949.331248',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-30'},
#  {'onset': '951.866476',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '963.108331',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-20'},
#  {'onset': '973.383331',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-20'},
#  {'onset': '984.441376',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-20'},
#  {'onset': '995.01607',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1001.53507',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '1009.593852',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1012.129125',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1027.791092',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-15'},
#  {'onset': '1032.734092',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-15'},
#  {'onset': '1043.786732',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-15'},
#  {'onset': '1054.361298',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '30'},
#  {'onset': '1061.830298',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '30'},
#  {'onset': '1070.890669',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '30'},
#  {'onset': '1073.425867',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '1083.566977',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1090.877977',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '1101.93096',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '1115.490485',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-30'},
#  {'onset': '1118.490485',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '1122.89696',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-30'},
#  {'onset': '1125.432252',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '1136.907599',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '1141.245599',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1150.301231',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '1161.876605',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '1167.021605',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1177.071675',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '1179.606882',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1192.600313',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': 'n/a'},
#  {'onset': '1200.694313',
#   'duration': '0',
#   'trial_type': 'decision_risky_solo',
#   'rewards': '-7.5'},
#  {'onset': '1211.748317',
#   'duration': '0',
#   'trial_type': 'outcome_self_pos_solo',
#   'rewards': '0'},
#  {'onset': '1217.318979',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1225.156979',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '0'},
#  {'onset': '1233.214511',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1235.749697',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1253.413602',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '30'},
#  {'onset': '1265.045602',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '30'},
#  {'onset': '1273.095128',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '30'},
#  {'onset': '1280.667331',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '0'},
#  {'onset': '1283.667331',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '1291.525599',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '0'},
#  {'onset': '1294.060885',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1301.933544',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1307.381544',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '9'},
#  {'onset': '1317.42882',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1326.001946',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '25'},
#  {'onset': '1332.868946',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '25'},
#  {'onset': '1339.929323',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '25'},
#  {'onset': '1342.464466',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '32'},
#  {'onset': '1355.758003',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '30'},
#  {'onset': '1358.758003',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '30'},
#  {'onset': '1367.350136',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '30'},
#  {'onset': '1373.921441',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '1380.220441',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1388.266282',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1390.801237',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1408.081464',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-15'},
#  {'onset': '1411.081464',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-15'},
#  {'onset': '1417.688532',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-15'},
#  {'onset': '1427.263315',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '1431.404315',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1439.455158',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '1441.990402',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1453.349179',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-15'},
#  {'onset': '1457.004179',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-15'},
#  {'onset': '1463.056746',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-15'},
#  {'onset': '1471.629709',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1475.652709',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '6'},
#  {'onset': '1485.707198',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '1488.24238',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1499.9513',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '1504.8203',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1510.87643',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1523.452588',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '10'},
#  {'onset': '1530.307588',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '10'},
#  {'onset': '1539.364813',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '10'},
#  {'onset': '1541.89997',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'}]

# %%
# 6)
sorted(entries, key=lambda d: d["rewards"])
# Out:
# [{'onset': '425.698328',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-10'},
#  {'onset': '428.698328',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-10'},
#  {'onset': '432.586891',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-10'},
#  {'onset': '886.166317',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-10'},
#  {'onset': '894.735317',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-10'},
#  {'onset': '902.795647',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-10'},
#  {'onset': '378.229089',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-15'},
#  {'onset': '381.229089',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-15'},
#  {'onset': '387.035498',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-15'},
#  {'onset': '1027.791092',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-15'},
#  {'onset': '1032.734092',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-15'},
#  {'onset': '1043.786732',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-15'},
#  {'onset': '1408.081464',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-15'},
#  {'onset': '1411.081464',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-15'},
#  {'onset': '1417.688532',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-15'},
#  {'onset': '1453.349179',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-15'},
#  {'onset': '1457.004179',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-15'},
#  {'onset': '1463.056746',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-15'},
#  {'onset': '395.608814',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-20'},
#  {'onset': '400.666814',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-20'},
#  {'onset': '409.71943',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-20'},
#  {'onset': '764.590285',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-20'},
#  {'onset': '767.590285',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-20'},
#  {'onset': '771.662329',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-20'},
#  {'onset': '857.444384',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-20'},
#  {'onset': '868.535384',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-20'},
#  {'onset': '877.5931',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-20'},
#  {'onset': '963.108331',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-20'},
#  {'onset': '973.383331',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-20'},
#  {'onset': '984.441376',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-20'},
#  {'onset': '197.857785',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-25'},
#  {'onset': '212.906785',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-25'},
#  {'onset': '218.957288',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-25'},
#  {'onset': '523.506321',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '533.417321',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '546.457133',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '732.699192',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '739.904192',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '749.962459',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '779.234763',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '785.175763',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '792.228033',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1373.921441',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '1380.220441',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1388.266282',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1499.9513',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '1504.8203',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1510.87643',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '668.467306',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-30'},
#  {'onset': '671.467306',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '676.439628',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-30'},
#  {'onset': '919.60851',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-30'},
#  {'onset': '922.60851',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '928.932253',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-30'},
#  {'onset': '936.504693',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-30'},
#  {'onset': '939.278693',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-30'},
#  {'onset': '949.331248',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-30'},
#  {'onset': '1115.490485',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-30'},
#  {'onset': '1118.490485',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '1122.89696',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-30'},
#  {'onset': '1200.694313',
#   'duration': '0',
#   'trial_type': 'decision_risky_solo',
#   'rewards': '-7.5'},
#  {'onset': '20.072093',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '27.661415',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '33.796415',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '42.856121',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '74.897329',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '85.472048',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '95.852048',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '108.889945',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '170.170194',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '182.227194',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '190.285498',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '265.909711',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_partner',
#   'rewards': '0'},
#  {'onset': '284.30704',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '306.390476',
#   'duration': '0',
#   'trial_type': 'outcome_self_neg_solo',
#   'rewards': '0'},
#  {'onset': '362.900485',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '475.570105',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '0'},
#  {'onset': '478.570105',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '484.826744',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '0'},
#  {'onset': '505.04221',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '580.800034',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '0'},
#  {'onset': '583.800034',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '588.005449',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '0'},
#  {'onset': '604.401331',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '618.979118',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '625.361118',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '633.406885',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '652.404718',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '692.068261',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '725.126869',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '816.046131',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '836.428364',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1009.593852',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1101.93096',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '1136.907599',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '1141.245599',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1150.301231',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '1161.876605',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '1167.021605',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1177.071675',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '1211.748317',
#   'duration': '0',
#   'trial_type': 'outcome_self_pos_solo',
#   'rewards': '0'},
#  {'onset': '1225.156979',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '0'},
#  {'onset': '1233.214511',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1280.667331',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '0'},
#  {'onset': '1283.667331',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '1291.525599',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '0'},
#  {'onset': '1317.42882',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1427.263315',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '1431.404315',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1439.455158',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '1485.707198',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '142.032034',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '10'},
#  {'onset': '145.179034',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '10'},
#  {'onset': '152.239768',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '10'},
#  {'onset': '352.850325',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '10'},
#  {'onset': '441.160085',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '10'},
#  {'onset': '450.962085',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '10'},
#  {'onset': '462.009382',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '10'},
#  {'onset': '554.029535',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '10'},
#  {'onset': '557.029535',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '10'},
#  {'onset': '560.934817',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '10'},
#  {'onset': '1523.452588',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '10'},
#  {'onset': '1530.307588',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '10'},
#  {'onset': '1539.364813',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '10'},
#  {'onset': '299.346961',
#   'duration': '0',
#   'trial_type': 'decision_risky_solo',
#   'rewards': '12.5'},
#  {'onset': '812.024403',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '13.5'},
#  {'onset': '232.567507',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '15'},
#  {'onset': '242.986507',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '15'},
#  {'onset': '250.031015',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '15'},
#  {'onset': '260.603337',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '18.5'},
#  {'onset': '125.419236',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '20'},
#  {'onset': '128.419236',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '20'},
#  {'onset': '132.457838',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '20'},
#  {'onset': '65.835578',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '1001.53507',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '1090.877977',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '500.386636',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '24.5'},
#  {'onset': '16',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '25'},
#  {'onset': '1326.001946',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '25'},
#  {'onset': '1332.868946',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '25'},
#  {'onset': '1339.929323',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '25'},
#  {'onset': '600.579626',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '27'},
#  {'onset': '319.617418',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '30'},
#  {'onset': '329.170418',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '30'},
#  {'onset': '336.230193',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '30'},
#  {'onset': '1054.361298',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '30'},
#  {'onset': '1061.830298',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '30'},
#  {'onset': '1070.890669',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '30'},
#  {'onset': '1253.413602',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '30'},
#  {'onset': '1265.045602',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '30'},
#  {'onset': '1273.095128',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '30'},
#  {'onset': '1355.758003',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '30'},
#  {'onset': '1358.758003',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '30'},
#  {'onset': '1367.350136',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '30'},
#  {'onset': '111.425148',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '32'},
#  {'onset': '1342.464466',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '32'},
#  {'onset': '45.391388',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '221.492477',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '268.444998',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '308.925866',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '838.963641',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '905.330966',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '951.866476',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1235.749697',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1294.060885',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1390.801237',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1441.990402',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '154.774905',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '365.43567',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '412.254679',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '464.544614',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '606.936571',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '752.497674',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '794.763228',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1012.129125',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1179.606882',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1488.24238',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1541.89997',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '507.577445',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '563.470099',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '694.603454',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '1073.425867',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '1125.432252',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '712.080534',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '4.5'},
#  {'onset': '654.939858',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '40'},
#  {'onset': '687.012275',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '42'},
#  {'onset': '827.36811',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '54'},
#  {'onset': '1475.652709',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '6'},
#  {'onset': '280.402022',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '7'},
#  {'onset': '646.360503',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '8.5'},
#  {'onset': '1307.381544',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '9'},
#  {'onset': '13',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '56.883578',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '257.603337',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '277.402022',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '290.878961',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': 'n/a'},
#  {'onset': '348.806325',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '497.386636',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '597.579626',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '639.978503',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '684.012275',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '707.663534',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '809.024403',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '822.61811',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '995.01607',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1083.566977',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1192.600313',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': 'n/a'},
#  {'onset': '1217.318979',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1301.933544',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1471.629709',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'}]

# %%
# 7)
sorted(entries, key=lambda d: d["rewards"], reverse=True)
# Out:
# [{'onset': '13',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '56.883578',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '257.603337',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '277.402022',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '290.878961',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': 'n/a'},
#  {'onset': '348.806325',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '497.386636',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '597.579626',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '639.978503',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '684.012275',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '707.663534',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '809.024403',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '822.61811',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '995.01607',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1083.566977',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1192.600313',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': 'n/a'},
#  {'onset': '1217.318979',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1301.933544',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1471.629709',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1307.381544',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '9'},
#  {'onset': '646.360503',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '8.5'},
#  {'onset': '280.402022',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '7'},
#  {'onset': '1475.652709',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '6'},
#  {'onset': '827.36811',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '54'},
#  {'onset': '687.012275',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '42'},
#  {'onset': '654.939858',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '40'},
#  {'onset': '712.080534',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '4.5'},
#  {'onset': '507.577445',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '563.470099',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '694.603454',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '1073.425867',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '1125.432252',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '154.774905',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '365.43567',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '412.254679',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '464.544614',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '606.936571',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '752.497674',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '794.763228',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1012.129125',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1179.606882',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1488.24238',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1541.89997',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '45.391388',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '221.492477',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '268.444998',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '308.925866',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '838.963641',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '905.330966',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '951.866476',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1235.749697',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1294.060885',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1390.801237',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1441.990402',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '111.425148',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '32'},
#  {'onset': '1342.464466',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '32'},
#  {'onset': '319.617418',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '30'},
#  {'onset': '329.170418',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '30'},
#  {'onset': '336.230193',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '30'},
#  {'onset': '1054.361298',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '30'},
#  {'onset': '1061.830298',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '30'},
#  {'onset': '1070.890669',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '30'},
#  {'onset': '1253.413602',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '30'},
#  {'onset': '1265.045602',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '30'},
#  {'onset': '1273.095128',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '30'},
#  {'onset': '1355.758003',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '30'},
#  {'onset': '1358.758003',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '30'},
#  {'onset': '1367.350136',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '30'},
#  {'onset': '600.579626',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '27'},
#  {'onset': '16',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '25'},
#  {'onset': '1326.001946',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '25'},
#  {'onset': '1332.868946',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '25'},
#  {'onset': '1339.929323',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '25'},
#  {'onset': '500.386636',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '24.5'},
#  {'onset': '65.835578',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '1001.53507',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '1090.877977',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '125.419236',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '20'},
#  {'onset': '128.419236',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '20'},
#  {'onset': '132.457838',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '20'},
#  {'onset': '260.603337',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '18.5'},
#  {'onset': '232.567507',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '15'},
#  {'onset': '242.986507',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '15'},
#  {'onset': '250.031015',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '15'},
#  {'onset': '812.024403',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '13.5'},
#  {'onset': '299.346961',
#   'duration': '0',
#   'trial_type': 'decision_risky_solo',
#   'rewards': '12.5'},
#  {'onset': '142.032034',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '10'},
#  {'onset': '145.179034',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '10'},
#  {'onset': '152.239768',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '10'},
#  {'onset': '352.850325',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '10'},
#  {'onset': '441.160085',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '10'},
#  {'onset': '450.962085',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '10'},
#  {'onset': '462.009382',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '10'},
#  {'onset': '554.029535',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '10'},
#  {'onset': '557.029535',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '10'},
#  {'onset': '560.934817',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '10'},
#  {'onset': '1523.452588',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '10'},
#  {'onset': '1530.307588',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '10'},
#  {'onset': '1539.364813',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '10'},
#  {'onset': '20.072093',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '27.661415',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '33.796415',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '42.856121',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '74.897329',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '85.472048',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '95.852048',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '108.889945',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '170.170194',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '182.227194',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '190.285498',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '265.909711',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_partner',
#   'rewards': '0'},
#  {'onset': '284.30704',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '306.390476',
#   'duration': '0',
#   'trial_type': 'outcome_self_neg_solo',
#   'rewards': '0'},
#  {'onset': '362.900485',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '475.570105',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '0'},
#  {'onset': '478.570105',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '484.826744',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '0'},
#  {'onset': '505.04221',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '580.800034',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '0'},
#  {'onset': '583.800034',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '588.005449',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '0'},
#  {'onset': '604.401331',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '618.979118',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '625.361118',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '633.406885',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '652.404718',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '692.068261',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '725.126869',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '816.046131',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '836.428364',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1009.593852',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1101.93096',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '1136.907599',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '1141.245599',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1150.301231',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '1161.876605',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '1167.021605',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1177.071675',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '1211.748317',
#   'duration': '0',
#   'trial_type': 'outcome_self_pos_solo',
#   'rewards': '0'},
#  {'onset': '1225.156979',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '0'},
#  {'onset': '1233.214511',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1280.667331',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '0'},
#  {'onset': '1283.667331',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '1291.525599',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '0'},
#  {'onset': '1317.42882',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1427.263315',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '1431.404315',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1439.455158',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '1485.707198',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '1200.694313',
#   'duration': '0',
#   'trial_type': 'decision_risky_solo',
#   'rewards': '-7.5'},
#  {'onset': '668.467306',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-30'},
#  {'onset': '671.467306',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '676.439628',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-30'},
#  {'onset': '919.60851',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-30'},
#  {'onset': '922.60851',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '928.932253',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-30'},
#  {'onset': '936.504693',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-30'},
#  {'onset': '939.278693',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-30'},
#  {'onset': '949.331248',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-30'},
#  {'onset': '1115.490485',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-30'},
#  {'onset': '1118.490485',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '1122.89696',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-30'},
#  {'onset': '197.857785',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-25'},
#  {'onset': '212.906785',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-25'},
#  {'onset': '218.957288',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-25'},
#  {'onset': '523.506321',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '533.417321',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '546.457133',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '732.699192',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '739.904192',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '749.962459',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '779.234763',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '785.175763',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '792.228033',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1373.921441',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '1380.220441',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1388.266282',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1499.9513',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '1504.8203',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1510.87643',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '395.608814',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-20'},
#  {'onset': '400.666814',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-20'},
#  {'onset': '409.71943',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-20'},
#  {'onset': '764.590285',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-20'},
#  {'onset': '767.590285',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-20'},
#  {'onset': '771.662329',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-20'},
#  {'onset': '857.444384',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-20'},
#  {'onset': '868.535384',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-20'},
#  {'onset': '877.5931',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-20'},
#  {'onset': '963.108331',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-20'},
#  {'onset': '973.383331',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-20'},
#  {'onset': '984.441376',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-20'},
#  {'onset': '378.229089',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-15'},
#  {'onset': '381.229089',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-15'},
#  {'onset': '387.035498',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-15'},
#  {'onset': '1027.791092',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-15'},
#  {'onset': '1032.734092',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-15'},
#  {'onset': '1043.786732',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-15'},
#  {'onset': '1408.081464',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-15'},
#  {'onset': '1411.081464',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-15'},
#  {'onset': '1417.688532',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-15'},
#  {'onset': '1453.349179',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-15'},
#  {'onset': '1457.004179',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-15'},
#  {'onset': '1463.056746',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-15'},
#  {'onset': '425.698328',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-10'},
#  {'onset': '428.698328',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-10'},
#  {'onset': '432.586891',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-10'},
#  {'onset': '886.166317',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-10'},
#  {'onset': '894.735317',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-10'},
#  {'onset': '902.795647',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-10'}]

# %%
set(d["trial_type"]for d in entries)
# Out:
# {'decision_risky_partner',
#  'decision_risky_social',
#  'decision_risky_solo',
#  'decision_safe_partner',
#  'decision_safe_social',
#  'decision_safe_solo',
#  'happiness_rating',
#  'options_partner',
#  'options_social',
#  'options_solo',
#  'outcome_other_neg_partner',
#  'outcome_other_neg_social',
#  'outcome_other_pos_partner',
#  'outcome_other_pos_social',
#  'outcome_safe_partner',
#  'outcome_safe_social',
#  'outcome_safe_solo',
#  'outcome_self_neg_solo',
#  'outcome_self_pos_solo'}

# %%
counts = {}
for d in entries:
    typ = d["trial_type"]
    if typ in counts:
        counts[typ] += 1
    else:
        counts[typ] = 1

# %%
counts
# Out:
# {'options_partner': 20,
#  'decision_risky_partner': 7,
#  'outcome_other_neg_partner': 6,
#  'options_solo': 20,
#  'decision_safe_solo': 18,
#  'outcome_safe_solo': 18,
#  'happiness_rating': 30,
#  'options_social': 20,
#  'decision_risky_social': 10,
#  'outcome_other_pos_social': 6,
#  'decision_safe_partner': 13,
#  'outcome_safe_partner': 13,
#  'decision_safe_social': 10,
#  'outcome_safe_social': 10,
#  'outcome_other_pos_partner': 1,
#  'decision_risky_solo': 2,
#  'outcome_self_neg_solo': 1,
#  'outcome_other_neg_social': 4,
#  'outcome_self_pos_solo': 1}

# %%
from collections import Counter

Counter(d["trial_type"] for d in entries)
# Out:
# Counter({'happiness_rating': 30,
#          'options_partner': 20,
#          'options_solo': 20,
#          'options_social': 20,
#          'decision_safe_solo': 18,
#          'outcome_safe_solo': 18,
#          'decision_safe_partner': 13,
#          'outcome_safe_partner': 13,
#          'decision_risky_social': 10,
#          'decision_safe_social': 10,
#          'outcome_safe_social': 10,
#          'decision_risky_partner': 7,
#          'outcome_other_neg_partner': 6,
#          'outcome_other_pos_social': 6,
#          'outcome_other_neg_social': 4,
#          'decision_risky_solo': 2,
#          'outcome_other_pos_partner': 1,
#          'outcome_self_neg_solo': 1,
#          'outcome_self_pos_solo': 1})

# %% [markdown]
# 10)

# %%
[e for e in entries if e["trial_type"].startswith("decision_")]
# Out:
# [{'onset': '16',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '25'},
#  {'onset': '33.796415',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '65.835578',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '95.852048',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '128.419236',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '20'},
#  {'onset': '145.179034',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '10'},
#  {'onset': '182.227194',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '212.906785',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-25'},
#  {'onset': '242.986507',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '15'},
#  {'onset': '260.603337',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '18.5'},
#  {'onset': '280.402022',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '7'},
#  {'onset': '299.346961',
#   'duration': '0',
#   'trial_type': 'decision_risky_solo',
#   'rewards': '12.5'},
#  {'onset': '329.170418',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '30'},
#  {'onset': '352.850325',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '10'},
#  {'onset': '381.229089',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-15'},
#  {'onset': '400.666814',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-20'},
#  {'onset': '428.698328',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-10'},
#  {'onset': '450.962085',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '10'},
#  {'onset': '478.570105',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '500.386636',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '24.5'},
#  {'onset': '533.417321',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '557.029535',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '10'},
#  {'onset': '583.800034',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '600.579626',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '27'},
#  {'onset': '625.361118',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '646.360503',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '8.5'},
#  {'onset': '671.467306',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '687.012275',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '42'},
#  {'onset': '712.080534',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '4.5'},
#  {'onset': '739.904192',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '767.590285',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-20'},
#  {'onset': '785.175763',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '812.024403',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '13.5'},
#  {'onset': '827.36811',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '54'},
#  {'onset': '868.535384',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-20'},
#  {'onset': '894.735317',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-10'},
#  {'onset': '922.60851',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '939.278693',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-30'},
#  {'onset': '973.383331',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-20'},
#  {'onset': '1001.53507',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '1032.734092',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-15'},
#  {'onset': '1061.830298',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '30'},
#  {'onset': '1090.877977',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '1118.490485',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '1141.245599',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1167.021605',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1200.694313',
#   'duration': '0',
#   'trial_type': 'decision_risky_solo',
#   'rewards': '-7.5'},
#  {'onset': '1225.156979',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '0'},
#  {'onset': '1265.045602',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '30'},
#  {'onset': '1283.667331',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '1307.381544',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '9'},
#  {'onset': '1332.868946',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '25'},
#  {'onset': '1358.758003',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '30'},
#  {'onset': '1380.220441',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1411.081464',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-15'},
#  {'onset': '1431.404315',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1457.004179',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-15'},
#  {'onset': '1475.652709',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '6'},
#  {'onset': '1504.8203',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1530.307588',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '10'}]

# %% [markdown]
# 11)

# %%
for e in entries:
    print(f"For the trial type: {e['trial_type']} the reward is {e['rewards']}")
# Out:
# For the trial type: options_partner the reward is n/a
# For the trial type: decision_risky_partner the reward is 25
# For the trial type: outcome_other_neg_partner the reward is 0
# For the trial type: options_solo the reward is 0
# For the trial type: decision_safe_solo the reward is 0
# For the trial type: outcome_safe_solo the reward is 0
# For the trial type: happiness_rating the reward is 34
# For the trial type: options_social the reward is n/a
# For the trial type: decision_risky_social the reward is 21
# For the trial type: outcome_other_pos_social the reward is 0
# For the trial type: options_solo the reward is 0
# For the trial type: decision_safe_solo the reward is 0
# For the trial type: outcome_safe_solo the reward is 0
# For the trial type: happiness_rating the reward is 32
# For the trial type: options_partner the reward is 20
# For the trial type: decision_safe_partner the reward is 20
# For the trial type: outcome_safe_partner the reward is 20
# For the trial type: options_social the reward is 10
# For the trial type: decision_safe_social the reward is 10
# For the trial type: outcome_safe_social the reward is 10
# For the trial type: happiness_rating the reward is 36
# For the trial type: options_solo the reward is 0
# For the trial type: decision_safe_solo the reward is 0
# For the trial type: outcome_safe_solo the reward is 0
# For the trial type: options_social the reward is -25
# For the trial type: decision_safe_social the reward is -25
# For the trial type: outcome_safe_social the reward is -25
# For the trial type: happiness_rating the reward is 34
# For the trial type: options_social the reward is 15
# For the trial type: decision_safe_social the reward is 15
# For the trial type: outcome_safe_social the reward is 15
# For the trial type: options_partner the reward is n/a
# For the trial type: decision_risky_partner the reward is 18.5
# For the trial type: outcome_other_pos_partner the reward is 0
# For the trial type: happiness_rating the reward is 34
# For the trial type: options_partner the reward is n/a
# For the trial type: decision_risky_partner the reward is 7
# For the trial type: outcome_other_neg_partner the reward is 0
# For the trial type: options_solo the reward is n/a
# For the trial type: decision_risky_solo the reward is 12.5
# For the trial type: outcome_self_neg_solo the reward is 0
# For the trial type: happiness_rating the reward is 34
# For the trial type: options_solo the reward is 30
# For the trial type: decision_safe_solo the reward is 30
# For the trial type: outcome_safe_solo the reward is 30
# For the trial type: options_social the reward is n/a
# For the trial type: decision_risky_social the reward is 10
# For the trial type: outcome_other_neg_social the reward is 0
# For the trial type: happiness_rating the reward is 36
# For the trial type: options_partner the reward is -15
# For the trial type: decision_safe_partner the reward is -15
# For the trial type: outcome_safe_partner the reward is -15
# For the trial type: options_solo the reward is -20
# For the trial type: decision_safe_solo the reward is -20
# For the trial type: outcome_safe_solo the reward is -20
# For the trial type: happiness_rating the reward is 36
# For the trial type: options_partner the reward is -10
# For the trial type: decision_safe_partner the reward is -10
# For the trial type: outcome_safe_partner the reward is -10
# For the trial type: options_solo the reward is 10
# For the trial type: decision_safe_solo the reward is 10
# For the trial type: outcome_safe_solo the reward is 10
# For the trial type: happiness_rating the reward is 36
# For the trial type: options_partner the reward is 0
# For the trial type: decision_safe_partner the reward is 0
# For the trial type: outcome_safe_partner the reward is 0
# For the trial type: options_partner the reward is n/a
# For the trial type: decision_risky_partner the reward is 24.5
# For the trial type: outcome_other_neg_partner the reward is 0
# For the trial type: happiness_rating the reward is 38
# For the trial type: options_solo the reward is -25
# For the trial type: decision_safe_solo the reward is -25
# For the trial type: outcome_safe_solo the reward is -25
# For the trial type: options_partner the reward is 10
# For the trial type: decision_safe_partner the reward is 10
# For the trial type: outcome_safe_partner the reward is 10
# For the trial type: happiness_rating the reward is 38
# For the trial type: options_partner the reward is 0
# For the trial type: decision_safe_partner the reward is 0
# For the trial type: outcome_safe_partner the reward is 0
# For the trial type: options_partner the reward is n/a
# For the trial type: decision_risky_partner the reward is 27
# For the trial type: outcome_other_neg_partner the reward is 0
# For the trial type: happiness_rating the reward is 36
# For the trial type: options_solo the reward is 0
# For the trial type: decision_safe_solo the reward is 0
# For the trial type: outcome_safe_solo the reward is 0
# For the trial type: options_social the reward is n/a
# For the trial type: decision_risky_social the reward is 8.5
# For the trial type: outcome_other_neg_social the reward is 0
# For the trial type: happiness_rating the reward is 40
# For the trial type: options_partner the reward is -30
# For the trial type: decision_safe_partner the reward is -30
# For the trial type: outcome_safe_partner the reward is -30
# For the trial type: options_partner the reward is n/a
# For the trial type: decision_risky_partner the reward is 42
# For the trial type: outcome_other_neg_partner the reward is 0
# For the trial type: happiness_rating the reward is 38
# For the trial type: options_social the reward is n/a
# For the trial type: decision_risky_social the reward is 4.5
# For the trial type: outcome_other_pos_social the reward is 0
# For the trial type: options_solo the reward is -25
# For the trial type: decision_safe_solo the reward is -25
# For the trial type: outcome_safe_solo the reward is -25
# For the trial type: happiness_rating the reward is 36
# For the trial type: options_partner the reward is -20
# For the trial type: decision_safe_partner the reward is -20
# For the trial type: outcome_safe_partner the reward is -20
# For the trial type: options_solo the reward is -25
# For the trial type: decision_safe_solo the reward is -25
# For the trial type: outcome_safe_solo the reward is -25
# For the trial type: happiness_rating the reward is 36
# For the trial type: options_partner the reward is n/a
# For the trial type: decision_risky_partner the reward is 13.5
# For the trial type: outcome_other_neg_partner the reward is 0
# For the trial type: options_social the reward is n/a
# For the trial type: decision_risky_social the reward is 54
# For the trial type: outcome_other_pos_social the reward is 0
# For the trial type: happiness_rating the reward is 34
# For the trial type: options_social the reward is -20
# For the trial type: decision_safe_social the reward is -20
# For the trial type: outcome_safe_social the reward is -20
# For the trial type: options_solo the reward is -10
# For the trial type: decision_safe_solo the reward is -10
# For the trial type: outcome_safe_solo the reward is -10
# For the trial type: happiness_rating the reward is 34
# For the trial type: options_partner the reward is -30
# For the trial type: decision_safe_partner the reward is -30
# For the trial type: outcome_safe_partner the reward is -30
# For the trial type: options_social the reward is -30
# For the trial type: decision_safe_social the reward is -30
# For the trial type: outcome_safe_social the reward is -30
# For the trial type: happiness_rating the reward is 34
# For the trial type: options_social the reward is -20
# For the trial type: decision_safe_social the reward is -20
# For the trial type: outcome_safe_social the reward is -20
# For the trial type: options_social the reward is n/a
# For the trial type: decision_risky_social the reward is 21
# For the trial type: outcome_other_pos_social the reward is 0
# For the trial type: happiness_rating the reward is 36
# For the trial type: options_social the reward is -15
# For the trial type: decision_safe_social the reward is -15
# For the trial type: outcome_safe_social the reward is -15
# For the trial type: options_social the reward is 30
# For the trial type: decision_safe_social the reward is 30
# For the trial type: outcome_safe_social the reward is 30
# For the trial type: happiness_rating the reward is 38
# For the trial type: options_social the reward is n/a
# For the trial type: decision_risky_social the reward is 21
# For the trial type: outcome_other_neg_social the reward is 0
# For the trial type: options_partner the reward is -30
# For the trial type: decision_safe_partner the reward is -30
# For the trial type: outcome_safe_partner the reward is -30
# For the trial type: happiness_rating the reward is 38
# For the trial type: options_solo the reward is 0
# For the trial type: decision_safe_solo the reward is 0
# For the trial type: outcome_safe_solo the reward is 0
# For the trial type: options_solo the reward is 0
# For the trial type: decision_safe_solo the reward is 0
# For the trial type: outcome_safe_solo the reward is 0
# For the trial type: happiness_rating the reward is 36
# For the trial type: options_solo the reward is n/a
# For the trial type: decision_risky_solo the reward is -7.5
# For the trial type: outcome_self_pos_solo the reward is 0
# For the trial type: options_social the reward is n/a
# For the trial type: decision_risky_social the reward is 0
# For the trial type: outcome_other_pos_social the reward is 0
# For the trial type: happiness_rating the reward is 34
# For the trial type: options_solo the reward is 30
# For the trial type: decision_safe_solo the reward is 30
# For the trial type: outcome_safe_solo the reward is 30
# For the trial type: options_partner the reward is 0
# For the trial type: decision_safe_partner the reward is 0
# For the trial type: outcome_safe_partner the reward is 0
# For the trial type: happiness_rating the reward is 34
# For the trial type: options_social the reward is n/a
# For the trial type: decision_risky_social the reward is 9
# For the trial type: outcome_other_pos_social the reward is 0
# For the trial type: options_solo the reward is 25
# For the trial type: decision_safe_solo the reward is 25
# For the trial type: outcome_safe_solo the reward is 25
# For the trial type: happiness_rating the reward is 32
# For the trial type: options_partner the reward is 30
# For the trial type: decision_safe_partner the reward is 30
# For the trial type: outcome_safe_partner the reward is 30
# For the trial type: options_solo the reward is -25
# For the trial type: decision_safe_solo the reward is -25
# For the trial type: outcome_safe_solo the reward is -25
# For the trial type: happiness_rating the reward is 34
# For the trial type: options_partner the reward is -15
# For the trial type: decision_safe_partner the reward is -15
# For the trial type: outcome_safe_partner the reward is -15
# For the trial type: options_solo the reward is 0
# For the trial type: decision_safe_solo the reward is 0
# For the trial type: outcome_safe_solo the reward is 0
# For the trial type: happiness_rating the reward is 34
# For the trial type: options_social the reward is -15
# For the trial type: decision_safe_social the reward is -15
# For the trial type: outcome_safe_social the reward is -15
# For the trial type: options_social the reward is n/a
# For the trial type: decision_risky_social the reward is 6
# For the trial type: outcome_other_neg_social the reward is 0
# For the trial type: happiness_rating the reward is 36
# For the trial type: options_solo the reward is -25
# For the trial type: decision_safe_solo the reward is -25
# For the trial type: outcome_safe_solo the reward is -25
# For the trial type: options_social the reward is 10
# For the trial type: decision_safe_social the reward is 10
# For the trial type: outcome_safe_social the reward is 10
# For the trial type: happiness_rating the reward is 36

# %% [markdown]
# 12)

# %%
def cleanup(rawinput):
    entries = []
    for i, line in enumerate(lines):
        if i == 0:
            continue
        o, d, t, r = line.split()
        entries.append({
            "onset": o,
            "duration": d,
            "trial_type": t,
            "rewards": r, 
        })
    return entries

# %%
cleanup(RAWDATA)
# Out:
# [{'onset': '13',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '16',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '25'},
#  {'onset': '20.072093',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '27.661415',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '33.796415',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '42.856121',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '45.391388',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '56.883578',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '65.835578',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '74.897329',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '85.472048',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '95.852048',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '108.889945',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '111.425148',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '32'},
#  {'onset': '125.419236',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '20'},
#  {'onset': '128.419236',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '20'},
#  {'onset': '132.457838',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '20'},
#  {'onset': '142.032034',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '10'},
#  {'onset': '145.179034',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '10'},
#  {'onset': '152.239768',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '10'},
#  {'onset': '154.774905',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '170.170194',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '182.227194',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '190.285498',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '197.857785',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-25'},
#  {'onset': '212.906785',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-25'},
#  {'onset': '218.957288',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-25'},
#  {'onset': '221.492477',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '232.567507',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '15'},
#  {'onset': '242.986507',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '15'},
#  {'onset': '250.031015',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '15'},
#  {'onset': '257.603337',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '260.603337',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '18.5'},
#  {'onset': '265.909711',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_partner',
#   'rewards': '0'},
#  {'onset': '268.444998',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '277.402022',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '280.402022',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '7'},
#  {'onset': '284.30704',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '290.878961',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': 'n/a'},
#  {'onset': '299.346961',
#   'duration': '0',
#   'trial_type': 'decision_risky_solo',
#   'rewards': '12.5'},
#  {'onset': '306.390476',
#   'duration': '0',
#   'trial_type': 'outcome_self_neg_solo',
#   'rewards': '0'},
#  {'onset': '308.925866',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '319.617418',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '30'},
#  {'onset': '329.170418',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '30'},
#  {'onset': '336.230193',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '30'},
#  {'onset': '348.806325',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '352.850325',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '10'},
#  {'onset': '362.900485',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '365.43567',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '378.229089',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-15'},
#  {'onset': '381.229089',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-15'},
#  {'onset': '387.035498',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-15'},
#  {'onset': '395.608814',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-20'},
#  {'onset': '400.666814',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-20'},
#  {'onset': '409.71943',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-20'},
#  {'onset': '412.254679',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '425.698328',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-10'},
#  {'onset': '428.698328',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-10'},
#  {'onset': '432.586891',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-10'},
#  {'onset': '441.160085',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '10'},
#  {'onset': '450.962085',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '10'},
#  {'onset': '462.009382',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '10'},
#  {'onset': '464.544614',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '475.570105',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '0'},
#  {'onset': '478.570105',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '484.826744',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '0'},
#  {'onset': '497.386636',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '500.386636',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '24.5'},
#  {'onset': '505.04221',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '507.577445',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '523.506321',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '533.417321',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '546.457133',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '554.029535',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '10'},
#  {'onset': '557.029535',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '10'},
#  {'onset': '560.934817',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '10'},
#  {'onset': '563.470099',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '580.800034',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '0'},
#  {'onset': '583.800034',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '588.005449',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '0'},
#  {'onset': '597.579626',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '600.579626',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '27'},
#  {'onset': '604.401331',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '606.936571',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '618.979118',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '625.361118',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '633.406885',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '639.978503',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '646.360503',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '8.5'},
#  {'onset': '652.404718',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '654.939858',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '40'},
#  {'onset': '668.467306',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-30'},
#  {'onset': '671.467306',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '676.439628',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-30'},
#  {'onset': '684.012275',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '687.012275',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '42'},
#  {'onset': '692.068261',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '694.603454',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '707.663534',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '712.080534',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '4.5'},
#  {'onset': '725.126869',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '732.699192',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '739.904192',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '749.962459',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '752.497674',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '764.590285',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-20'},
#  {'onset': '767.590285',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-20'},
#  {'onset': '771.662329',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-20'},
#  {'onset': '779.234763',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '785.175763',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '792.228033',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '794.763228',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '809.024403',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': 'n/a'},
#  {'onset': '812.024403',
#   'duration': '0',
#   'trial_type': 'decision_risky_partner',
#   'rewards': '13.5'},
#  {'onset': '816.046131',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_partner',
#   'rewards': '0'},
#  {'onset': '822.61811',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '827.36811',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '54'},
#  {'onset': '836.428364',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '838.963641',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '857.444384',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-20'},
#  {'onset': '868.535384',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-20'},
#  {'onset': '877.5931',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-20'},
#  {'onset': '886.166317',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-10'},
#  {'onset': '894.735317',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-10'},
#  {'onset': '902.795647',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-10'},
#  {'onset': '905.330966',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '919.60851',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-30'},
#  {'onset': '922.60851',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '928.932253',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-30'},
#  {'onset': '936.504693',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-30'},
#  {'onset': '939.278693',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-30'},
#  {'onset': '949.331248',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-30'},
#  {'onset': '951.866476',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '963.108331',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-20'},
#  {'onset': '973.383331',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-20'},
#  {'onset': '984.441376',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-20'},
#  {'onset': '995.01607',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1001.53507',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '1009.593852',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1012.129125',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1027.791092',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-15'},
#  {'onset': '1032.734092',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-15'},
#  {'onset': '1043.786732',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-15'},
#  {'onset': '1054.361298',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '30'},
#  {'onset': '1061.830298',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '30'},
#  {'onset': '1070.890669',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '30'},
#  {'onset': '1073.425867',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '1083.566977',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1090.877977',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '21'},
#  {'onset': '1101.93096',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '1115.490485',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-30'},
#  {'onset': '1118.490485',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-30'},
#  {'onset': '1122.89696',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-30'},
#  {'onset': '1125.432252',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '38'},
#  {'onset': '1136.907599',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '1141.245599',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1150.301231',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '1161.876605',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '1167.021605',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1177.071675',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '1179.606882',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1192.600313',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': 'n/a'},
#  {'onset': '1200.694313',
#   'duration': '0',
#   'trial_type': 'decision_risky_solo',
#   'rewards': '-7.5'},
#  {'onset': '1211.748317',
#   'duration': '0',
#   'trial_type': 'outcome_self_pos_solo',
#   'rewards': '0'},
#  {'onset': '1217.318979',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1225.156979',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '0'},
#  {'onset': '1233.214511',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1235.749697',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1253.413602',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '30'},
#  {'onset': '1265.045602',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '30'},
#  {'onset': '1273.095128',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '30'},
#  {'onset': '1280.667331',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '0'},
#  {'onset': '1283.667331',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '0'},
#  {'onset': '1291.525599',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '0'},
#  {'onset': '1294.060885',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1301.933544',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1307.381544',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '9'},
#  {'onset': '1317.42882',
#   'duration': '0',
#   'trial_type': 'outcome_other_pos_social',
#   'rewards': '0'},
#  {'onset': '1326.001946',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '25'},
#  {'onset': '1332.868946',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '25'},
#  {'onset': '1339.929323',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '25'},
#  {'onset': '1342.464466',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '32'},
#  {'onset': '1355.758003',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '30'},
#  {'onset': '1358.758003',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '30'},
#  {'onset': '1367.350136',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '30'},
#  {'onset': '1373.921441',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '1380.220441',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1388.266282',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1390.801237',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1408.081464',
#   'duration': '0',
#   'trial_type': 'options_partner',
#   'rewards': '-15'},
#  {'onset': '1411.081464',
#   'duration': '0',
#   'trial_type': 'decision_safe_partner',
#   'rewards': '-15'},
#  {'onset': '1417.688532',
#   'duration': '0',
#   'trial_type': 'outcome_safe_partner',
#   'rewards': '-15'},
#  {'onset': '1427.263315',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '0'},
#  {'onset': '1431.404315',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '0'},
#  {'onset': '1439.455158',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '0'},
#  {'onset': '1441.990402',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '34'},
#  {'onset': '1453.349179',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '-15'},
#  {'onset': '1457.004179',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '-15'},
#  {'onset': '1463.056746',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '-15'},
#  {'onset': '1471.629709',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': 'n/a'},
#  {'onset': '1475.652709',
#   'duration': '0',
#   'trial_type': 'decision_risky_social',
#   'rewards': '6'},
#  {'onset': '1485.707198',
#   'duration': '0',
#   'trial_type': 'outcome_other_neg_social',
#   'rewards': '0'},
#  {'onset': '1488.24238',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'},
#  {'onset': '1499.9513',
#   'duration': '0',
#   'trial_type': 'options_solo',
#   'rewards': '-25'},
#  {'onset': '1504.8203',
#   'duration': '0',
#   'trial_type': 'decision_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1510.87643',
#   'duration': '0',
#   'trial_type': 'outcome_safe_solo',
#   'rewards': '-25'},
#  {'onset': '1523.452588',
#   'duration': '0',
#   'trial_type': 'options_social',
#   'rewards': '10'},
#  {'onset': '1530.307588',
#   'duration': '0',
#   'trial_type': 'decision_safe_social',
#   'rewards': '10'},
#  {'onset': '1539.364813',
#   'duration': '0',
#   'trial_type': 'outcome_safe_social',
#   'rewards': '10'},
#  {'onset': '1541.89997',
#   'duration': '0',
#   'trial_type': 'happiness_rating',
#   'rewards': '36'}]
